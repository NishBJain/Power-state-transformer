# %%
import pandas as pd  
import numpy as np

# %%
dataset = pd.read_csv("final2.csv")

# %%
dataset.head()
# Out:
#    EvaluationState  Voltage, kV  Winding arrangement  Switching devices  \
# 0                1          110                    3                  3
# 1                1          110                    3                  3
# 2                1          110                    3                  3
# 3                0          110                    3                  3
# 4                1          110                    3                  3
#
#    Oil year  Breakdown voltage, kV  Moisture content, g/t  \
# 0      1968               73600000               18000000
# 1      1958               64800000               19800000
# 2      1983               72000000               23000000
# 3      1973               41200000               13850000
# 4      1957               46000000               13850000
#
#    Acid number, mgKOH/g  Oil tangent at 90С, %  \
# 0               1610000                  17000
# 1                630000                  30000
# 2                 40000                   7500
# 3               1706000                  20000
# 4               1706000                  28000
#
#    Concentration of  ionol additive, %  \
# 0                               160000
# 1                               160000
# 2                               160000
# 3                               160000
# 4                               160000
#
#                                              ...                                              \
# 0                                            ...
# 1                                            ...
# 2                                            ...
# 3                                            ...
# 4                                            ...
#
#    С2Н6, % vol.  С2Н2, % vol.  СО2, % vol.  СО, % vol.  \
# 0           100            60       200000      150000
# 1          3000             0       520000       37000
# 2             0            40        90000        7000
# 3           100          3100       160000       17000
# 4           700          3100       460000       27000
#
#    Noload losses, measured during commissioning tests with a shortcircuited phase "a", W  \
# 0                                          313600000
# 1                                          313600000
# 2                                          313600000
# 3                                          313600000
# 4                                          313600000
#
#    Noload losses, measured during commissioning tests with a shortcircuited phase "b", W  \
# 0                                          321180000
# 1                                          321180000
# 2                                          321180000
# 3                                          321180000
# 4                                          321180000
#
#    Noload losses, measured during commissioning tests with a shortcircuited phase "c", W  \
# 0                                          318640000
# 1                                          318640000
# 2                                          318640000
# 3                                          318640000
# 4                                          318640000
#
#    Noload losses, measured during last operaational tests with a shortcircuited phase "a", W  \
# 0                                            3266600
# 1                                            9287400
# 2                                             800600
# 3                                              72315
# 4                                              72315
#
#    Noload losses, measured during last operaational tests with a shortcircuited phase "b", W  \
# 0                                            4739800
# 1                                           13130500
# 2                                            1152900
# 3                                             103690
# 4                                             103690
#
#    Noload losses, measured during last operaational tests with a shortcircuited phase "c", W
# 0                                            3138500
# 1                                            9287400
# 2                                             832600
# 3                                              73786
# 4                                              73786
#
# [5 rows x 24 columns]

# %%
X = dataset.iloc[:, 1:].values  
y = dataset.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()  
X_train = sc.fit_transform(X_train)  
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7155963302752294

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.plot(y_test)
ax.plot(y_pred)
